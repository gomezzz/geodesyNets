# %% [markdown]
# # Training Notebook
#
# First the imports:

# %%
# Import our module containing helper functions
import gravann
import gravann.polyhedral

# Core imports
import numpy as np
import pickle as pk
import os
from collections import deque

# pytorch
from torch import nn
import torch

# plotting stuff
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib notebook

# Ensure that changes in imported module (gravann most importantly) are autoreloaded
# %load_ext autoreload
# %autoreload 2

# If possible enable CUDA
gravann.enableCUDA()
gravann.fixRandomSeeds()
device = os.environ["TORCH_DEVICE"]
print("Will use device ",device)
# Out:
# C:\Users\josch\miniconda3\envs\geodesynet\lib\site-packages\pyvista\themes.py:131: PyVistaDeprecationWarning: use "dark" instead of "night" theme
#   warnings.warn('use "dark" instead of "night" theme', PyVistaDeprecationWarning)
# Available devices  1
# __pyTorch VERSION: 1.13.1
# __CUDNN VERSION: 8500
# __Number CUDA Devices: 1
# Active CUDA Device: GPU 0
# Setting default tensor type to Float32
# Will use device  cuda:0

# %% [markdown]
# ## 0 - Loading the ground truth (both mascon and polyhedral)

# %%
##################### PLEASE SPECIFY THIS ####################
# one of "eros", "bennu", "itokawa", "churyumov-gerasimenko", "planetesimal", "torus", "bennu_nu", "itokawa_nu", "planetesimal_nu"
SAMPLE_NAME = "churyumov-gerasimenko"
# can be freely chosen
MODEL_NAME = "four"
# either 'mascon' or 'polyhedral'
MODEL_METHOD = 'polyhedral'

# Load an already trained and saved model (e.g. for re-training)?
LOAD_TRAINED = False
##############################################################

MODEL_FILENAME = f"models_polyhedral/{SAMPLE_NAME}_{MODEL_METHOD}_{MODEL_NAME}.mdl"

mesh_vertices, mesh_faces = gravann.load_polyhedral_mesh(SAMPLE_NAME)
density = gravann.polyhedral.calculate_density(mesh_vertices, mesh_faces)

# Only for the legacy plots required
mascon_points, mascon_masses = gravann.load_mascon_data(SAMPLE_NAME)

print(f"Chosen body: {SAMPLE_NAME}")
print(f"Loaded Polyhedral Mesh Data:")
print(f"Loaded the Mesh of {SAMPLE_NAME}")
print(f"Number of vertices: {len(mesh_vertices)}")
print(f"Number of faces (triangles): {len(mesh_faces)}")
print(f"Calculated Density: {density}")
# Out:
# Chosen body: churyumov-gerasimenko
# Loaded Polyhedral Mesh Data:
# Loaded the Mesh of churyumov-gerasimenko
# Number of vertices: 9149
# Number of faces (triangles): 18294
# Calculated Density: 1.6605502606980964

# %% [markdown]
# ## 1 - Defining the network architecture
# We here use functions from our module as to not clutter the notebook, but the code is rather straight forward: a FFNN with some options.

# %%
# Encoding: direct encoding (i.e. feeding the network directly with the Cartesian coordinates in the unit hypercube)
# was found to work well in most cases. But more options are implemented in the module.
encoding = gravann.direct_encoding()

# The model is here a SIREN network (FFNN with sin non linearities and a final absolute value to predict the density)
model = gravann.init_network(encoding, n_neurons=100, model_type="siren", activation = gravann.AbsLayer())
#model = gravann.init_network(encoding, n_neurons=100, model_type="siren", activation = gravann.SquaredReLU())
#model = gravann.init_network(encoding, n_neurons=100, model_type="siren", activation = torch.nn.ReLU())


# Init training logs
loss_log = []
weighted_average_log = []
running_loss_log = []
n_inferences = []
weighted_average = deque([], maxlen=20)

if LOAD_TRAINED:
    model.load_state_dict(torch.load(MODEL_FILENAME))

# Once a model is loaded the learned constant c (named kappa in the paper) is unknown
# and must be relearned (ideally it should also be saved at the end of the training as it is a learned parameter)
c = gravann.compute_c_for_model_v2(model, encoding, MODEL_METHOD,
                                   mascon_points=mascon_points,
                                   mascon_masses=mascon_masses,
                                   mesh_vertices=mesh_vertices,
                                   mesh_faces=mesh_faces,
                                   density=density,
                                   use_acc = True)
# Out:
# C:\Users\josch\miniconda3\envs\geodesynet\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3191.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %% [markdown]
# ## 2 - Visualizing the initial neural density field
# The network output is a mass density in the unit cube. Essentially a three dimensional function which we here plot via rejection sampling (for now this method is good enough)

# %%
# The rejection plot will visualize the neural density field as a probability distribution function. 
# Colors represent the density magnitude (white being zero). 
# At the beginning, the whole hypercube is filled with some non vanishing density.
gravann.plot_model_rejection(model, encoding, views_2d=True, N=10000, progressbar=True, c=c)
plt.title("Believe it or not I am an asteroid!")
# Out:
# Sampling points...: 11015it [00:01, 7119.51it/s]
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.0, 'Believe it or not I am an asteroid!')

# %% [markdown]
# # 3- Training of a geodesyNet
# Specify parameters if you're unhappy with the defaults

# %%
##################### PLEASE SPECIFY THIS ####################
# Number of iterations to train
NUMBER_OF_ITERATIONS = 10000

# Number of points to be used to evaluate numerically the triple integral
# defining the acceleration. 
# Use <=30000 to for a quick training ... 300000 was used to produce most of the paper results
N_QUADRATUR = 30000

# Dimension of the batch size, i.e. number of points
# where the ground truth is compared to the predicted acceleration
# at each training epoch.
# Use 100 for a quick training. 1000  was used to produce most of the paper results
BATCH_SIZE = 1000

# Loss. The normalized L1 loss (kMAE in the paper) was
# found to be one of the best performing choices.
# More are implemented in the module
LOSS_FN = gravann.normalized_L1_loss

# The numerical Integration method. 
# Trapezoidal integration is here set over a dataset containing acceleration values,
# (it is possible to also train on values of the gravity potential, results are similar)
MC_METHOD = gravann.ACC_trap

# Here we set the optimizer
LEARNING_RATE = 1e-4
OPTIMIZER = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
SCHEDULER = torch.optim.lr_scheduler.ReduceLROnPlateau(OPTIMIZER,factor = 0.8, patience = 200, min_lr = 1e-7,verbose=True)

##############################################################

LABEL_FUNCTIONS = {
    'polyhedral': lambda points: gravann.polyhedral.ACC_L(points, mesh_vertices, mesh_faces, density),
    'mascon': lambda points: gravann.ACC_L(points, mascon_points, mascon_masses)
}

label_fn = LABEL_FUNCTIONS[MODEL_METHOD]

# And init the best results
best_loss = np.inf
best_model_state_dict = model.state_dict()

# The sampling method to decide what points to consider in each batch.
# In this case we sample points unifromly in a sphere and reject those that are inside the asteroid
# Only for sampling the low poly resolution!!
targets_point_sampler = gravann.get_target_point_sampler(BATCH_SIZE,
                                                         limit_shape_to_asteroid=f"./3dmeshes/{SAMPLE_NAME}_lp.pk",
                                                         method="spherical",
                                                         bounds=[0,1])

# %% [markdown]
# **Note: the cell below is explicitly typed for convenience, as this is a tutorial-ish after all, but the module gravann contains a function (train_on_batch) that does the same**

# %%
# TRAINING LOOP (normal training, no use of any prior shape information)------------------------
# This cell can be stopped and started again without loosing memory of the training nor its logs
torch.cuda.empty_cache()
# The main training loop
for i in range(NUMBER_OF_ITERATIONS):
    # Each ten epochs we resample the target points
    if (i % 10 == 0):
        target_points = targets_point_sampler()
        # We compute the labels whenever the target points are changed
        labels = label_fn(target_points)
    
    # We compute the values predicted by the neural density field
    predicted = MC_METHOD(target_points, model, encoding, N=N_QUADRATUR, noise=0.)
    
    # We learn the scaling constant (k in the paper)
    c = torch.sum(predicted*labels)/torch.sum(predicted*predicted)
    
    # We compute the loss (note that the contrastive loss needs a different shape for the labels)
    if LOSS_FN == gravann.contrastive_loss:
       loss = LOSS_FN(predicted, labels)
    else:
       loss = LOSS_FN(predicted.view(-1), labels.view(-1))
    
    # We store the model if it has the lowest fitness 
    # (this is to avoid losing good results during a run that goes wild)
    if loss < best_loss:
        best_model_state_dict = model.state_dict()
        best_loss = loss
        print('New Best: ', loss.item())
        # Uncomment to save the model during training (careful it overwrites the model folder)
        #torch.save(model.state_dict(), "models/"+name_of_gt+".mdl")
    
    # Update the loss trend indicators
    weighted_average.append(loss.item())
    
    # Update the logs
    weighted_average_log.append(np.mean(weighted_average))
    loss_log.append(loss.item())
    n_inferences.append((N_QUADRATUR*BATCH_SIZE) // 1000000) #counted in millions
    
    # Print every i iterations
    if i % 25 == 0:
        wa_out = np.mean(weighted_average)
        print(f"It={i}\t loss={loss.item():.3e}\t  weighted_average={wa_out:.3e}\t  c={c:.3e}")
        
    # Zeroes the gradient (necessary because of things)
    OPTIMIZER.zero_grad()

    # Backward pass: compute gradient of the loss with respect to model parameters
    loss.backward()

    # Calling the step function on an Optimizer makes an update to its
    # parameters
    OPTIMIZER.step()
    
    # Perform a step in LR scheduler to update LR
    SCHEDULER.step(loss.item())
# Out:
# New Best:  0.36295706033706665
# It=0	 loss=3.630e-01	  weighted_average=3.630e-01	  c=5.549e+00
# New Best:  0.3328711688518524
# New Best:  0.3112766444683075
# New Best:  0.29065176844596863
# New Best:  0.26684096455574036
# New Best:  0.22373473644256592
# New Best:  0.20790234208106995
# New Best:  0.17730598151683807
# New Best:  0.1771971434354782
# New Best:  0.15044331550598145
# New Best:  0.14169646799564362
# New Best:  0.12013152241706848
# It=25	 loss=1.201e-01	  weighted_average=2.402e-01	  c=5.933e+00
# New Best:  0.10375618189573288
# New Best:  0.09613747149705887
# New Best:  0.08559668064117432
# New Best:  0.07397030293941498
# New Best:  0.0641275942325592
# New Best:  0.05634357035160065
# New Best:  0.04856766760349274
# New Best:  0.04339433088898659
# New Best:  0.037344884127378464
# New Best:  0.03315495327115059
# New Best:  0.03224717825651169
# It=50	 loss=4.067e-02	  weighted_average=5.733e-02	  c=5.536e+00
# New Best:  0.029836514964699745
# New Best:  0.029231781139969826
# New Best:  0.0273414459079504
# New Best:  0.027096645906567574
# New Best:  0.023655710741877556
# New Best:  0.02283901534974575
# New Best:  0.01971680112183094
# New Best:  0.016703378409147263
# New Best:  0.015564145520329475
# It=75	 loss=1.600e-02	  weighted_average=2.071e-02	  c=5.198e+00
# New Best:  0.014407805167138577
# New Best:  0.013793186284601688
# New Best:  0.013595804572105408
# New Best:  0.012669948861002922
# New Best:  0.011766026727855206
# New Best:  0.010150144807994366
# New Best:  0.009954515844583511
# New Best:  0.008987666107714176
# It=100	 loss=1.270e-02	  weighted_average=1.288e-02	  c=5.092e+00
# New Best:  0.008937526494264603
# New Best:  0.008837662637233734
# It=125	 loss=2.180e-02	  weighted_average=1.250e-02	  c=4.862e+00
# New Best:  0.008752740919589996
# New Best:  0.008583425544202328
# New Best:  0.007782989647239447
# New Best:  0.007095645647495985
# It=150	 loss=1.103e-02	  weighted_average=1.372e-02	  c=4.929e+00
# New Best:  0.006639465223997831
# New Best:  0.0065119280479848385
# New Best:  0.0061216820031404495
# New Best:  0.005525053478777409
# New Best:  0.005401945672929287
# It=175	 loss=7.084e-01	  weighted_average=1.345e-01	  c=3.483e-01
# It=200	 loss=4.023e-02	  weighted_average=9.442e-02	  c=4.865e+00
# It=225	 loss=3.887e-02	  weighted_average=5.375e-02	  c=5.441e+00
# It=250	 loss=2.239e-02	  weighted_average=2.425e-02	  c=5.502e+00
# It=275	 loss=1.552e-02	  weighted_average=1.928e-02	  c=5.490e+00
# It=300	 loss=1.782e-02	  weighted_average=1.469e-02	  c=5.602e+00
# It=325	 loss=1.521e-02	  weighted_average=1.368e-02	  c=5.707e+00
# It=350	 loss=1.104e-02	  weighted_average=1.294e-02	  c=5.852e+00
# Epoch 00370: reducing learning rate of group 0 to 8.0000e-05.
# It=375	 loss=1.262e-02	  weighted_average=1.786e-02	  c=5.394e+00
# It=400	 loss=8.156e-03	  weighted_average=1.032e-02	  c=5.589e+00
# It=425	 loss=7.422e-03	  weighted_average=7.863e-03	  c=5.730e+00
# It=450	 loss=6.977e-03	  weighted_average=7.369e-03	  c=5.786e+00
# It=475	 loss=6.723e-03	  weighted_average=7.848e-03	  c=5.838e+00
# It=500	 loss=7.956e-03	  weighted_average=6.702e-03	  c=5.888e+00
# New Best:  0.005236465018242598
# New Best:  0.005034341011196375
# It=525	 loss=5.034e-03	  weighted_average=6.377e-03	  c=5.835e+00
# It=550	 loss=5.440e-03	  weighted_average=6.302e-03	  c=5.962e+00
# New Best:  0.005003495141863823
# New Best:  0.004901262000203133
# New Best:  0.0048425160348415375
# It=575	 loss=5.402e-03	  weighted_average=5.999e-03	  c=5.968e+00
# New Best:  0.004719817079603672
# New Best:  0.004572877660393715
# New Best:  0.004483040887862444
# New Best:  0.004352246876806021
# It=600	 loss=4.935e-03	  weighted_average=5.334e-03	  c=6.001e+00
# New Best:  0.0043219951912760735
# New Best:  0.0039888774044811726
# It=625	 loss=7.181e-03	  weighted_average=5.743e-03	  c=5.976e+00
# It=650	 loss=6.114e-03	  weighted_average=5.505e-03	  c=6.054e+00
# It=675	 loss=5.708e-03	  weighted_average=5.356e-03	  c=6.075e+00
# It=700	 loss=7.259e-03	  weighted_average=6.365e-03	  c=5.935e+00
# It=725	 loss=5.234e-03	  weighted_average=4.985e-03	  c=5.890e+00
# It=750	 loss=5.307e-03	  weighted_average=5.271e-03	  c=5.924e+00
# New Best:  0.003955432679504156
# New Best:  0.003882666816934943
# New Best:  0.003680116031318903
# New Best:  0.003441296285018325
# New Best:  0.003358010668307543
# It=775	 loss=4.998e-03	  weighted_average=4.122e-03	  c=5.937e+00
# New Best:  0.003328748280182481
# New Best:  0.0033148371148854494
# It=800	 loss=4.011e-03	  weighted_average=4.114e-03	  c=5.974e+00
# It=825	 loss=4.573e-03	  weighted_average=4.102e-03	  c=5.973e+00
# It=850	 loss=3.579e-01	  weighted_average=2.223e-02	  c=3.279e+00
# It=875	 loss=2.096e-02	  weighted_average=3.029e-02	  c=4.789e+00
# It=900	 loss=1.407e-02	  weighted_average=1.487e-02	  c=5.162e+00
# It=925	 loss=1.041e-02	  weighted_average=1.081e-02	  c=5.196e+00
# It=950	 loss=8.825e-03	  weighted_average=8.966e-03	  c=5.324e+00
# It=975	 loss=6.614e-03	  weighted_average=7.997e-03	  c=5.437e+00
# Epoch 00999: reducing learning rate of group 0 to 6.4000e-05.
# It=1000	 loss=6.054e-03	  weighted_average=8.735e-03	  c=5.459e+00
# It=1025	 loss=7.271e-03	  weighted_average=6.766e-03	  c=5.485e+00
# It=1050	 loss=5.412e-03	  weighted_average=5.603e-03	  c=5.499e+00
# It=1075	 loss=4.746e-03	  weighted_average=5.377e-03	  c=5.532e+00
# It=1100	 loss=5.063e-03	  weighted_average=4.774e-03	  c=5.620e+00
# It=1125	 loss=4.512e-03	  weighted_average=4.300e-03	  c=5.665e+00
# It=1150	 loss=4.002e-03	  weighted_average=4.499e-03	  c=5.642e+00
# It=1175	 loss=4.247e-03	  weighted_average=4.545e-03	  c=5.691e+00
# Epoch 01200: reducing learning rate of group 0 to 5.1200e-05.
# It=1200	 loss=4.619e-03	  weighted_average=4.151e-03	  c=5.670e+00
# It=1225	 loss=4.622e-03	  weighted_average=4.554e-03	  c=5.690e+00
# New Best:  0.003199069993570447
# New Best:  0.003087433520704508
# It=1250	 loss=3.150e-03	  weighted_average=3.918e-03	  c=5.723e+00
# New Best:  0.0029986766166985035
# New Best:  0.002852609846740961
# New Best:  0.0027959232684224844
# New Best:  0.0027820139657706022
# It=1275	 loss=4.046e-03	  weighted_average=4.821e-03	  c=5.712e+00
# It=1300	 loss=3.362e-03	  weighted_average=3.619e-03	  c=5.744e+00
# It=1325	 loss=3.528e-03	  weighted_average=3.279e-03	  c=5.854e+00
# It=1350	 loss=2.030e-01	  weighted_average=1.866e-01	  c=3.644e+00
# It=1375	 loss=3.584e-02	  weighted_average=5.932e-02	  c=5.080e+00
# It=1400	 loss=2.174e-02	  weighted_average=2.753e-02	  c=4.869e+00
# It=1425	 loss=1.625e-02	  weighted_average=1.758e-02	  c=4.827e+00
# It=1450	 loss=1.441e-02	  weighted_average=1.456e-02	  c=4.971e+00
# Epoch 01460: reducing learning rate of group 0 to 4.0960e-05.
# It=1475	 loss=1.141e-02	  weighted_average=1.159e-02	  c=5.014e+00
# It=1500	 loss=1.207e-02	  weighted_average=1.037e-02	  c=4.987e+00
# It=1525	 loss=8.837e-03	  weighted_average=9.831e-03	  c=5.011e+00
# It=1550	 loss=1.102e-01	  weighted_average=3.955e-01	  c=3.806e+00
# It=1575	 loss=4.710e-02	  weighted_average=6.697e-02	  c=4.146e+00
# It=1600	 loss=3.279e-02	  weighted_average=3.545e-02	  c=4.184e+00
# It=1625	 loss=2.704e-02	  weighted_average=2.860e-02	  c=4.468e+00
# It=1650	 loss=2.205e-02	  weighted_average=2.345e-02	  c=4.566e+00
# Epoch 01661: reducing learning rate of group 0 to 3.2768e-05.
# It=1675	 loss=1.966e-02	  weighted_average=1.962e-02	  c=4.600e+00
# It=1700	 loss=1.771e-02	  weighted_average=1.790e-02	  c=4.571e+00
# It=1725	 loss=1.492e-02	  weighted_average=1.584e-02	  c=4.570e+00
# It=1750	 loss=1.542e-02	  weighted_average=1.465e-02	  c=4.616e+00
# It=1775	 loss=1.374e-02	  weighted_average=1.411e-02	  c=4.658e+00
# It=1800	 loss=1.208e-02	  weighted_average=1.321e-02	  c=4.699e+00
# It=1825	 loss=1.158e-02	  weighted_average=1.190e-02	  c=4.695e+00
# It=1850	 loss=1.191e-02	  weighted_average=1.075e-02	  c=4.712e+00
# Epoch 01862: reducing learning rate of group 0 to 2.6214e-05.
# It=1875	 loss=1.086e-02	  weighted_average=1.061e-02	  c=4.751e+00
# It=1900	 loss=1.021e-02	  weighted_average=1.003e-02	  c=4.789e+00
# It=1925	 loss=8.448e-03	  weighted_average=1.000e-02	  c=4.778e+00
# It=1950	 loss=8.709e-03	  weighted_average=8.824e-03	  c=4.752e+00
# It=1975	 loss=8.451e-03	  weighted_average=8.449e-03	  c=4.751e+00
# It=2000	 loss=9.792e-03	  weighted_average=9.053e-03	  c=4.741e+00
# It=2025	 loss=8.779e-03	  weighted_average=8.231e-03	  c=4.758e+00
# It=2050	 loss=8.259e-03	  weighted_average=8.365e-03	  c=4.798e+00
# Epoch 02063: reducing learning rate of group 0 to 2.0972e-05.
# It=2075	 loss=7.789e-03	  weighted_average=7.961e-03	  c=4.786e+00
# It=2100	 loss=8.693e-03	  weighted_average=7.658e-03	  c=4.813e+00
# It=2125	 loss=7.336e-03	  weighted_average=7.411e-03	  c=4.830e+00
# It=2150	 loss=6.703e-03	  weighted_average=7.271e-03	  c=4.838e+00
# It=2175	 loss=7.283e-03	  weighted_average=6.779e-03	  c=4.845e+00
# It=2200	 loss=7.009e-03	  weighted_average=7.354e-03	  c=4.852e+00
# It=2225	 loss=6.270e-03	  weighted_average=6.482e-03	  c=4.892e+00
# It=2250	 loss=6.310e-03	  weighted_average=6.998e-03	  c=4.912e+00
# Epoch 02264: reducing learning rate of group 0 to 1.6777e-05.
# It=2275	 loss=5.930e-03	  weighted_average=6.298e-03	  c=4.884e+00
# It=2300	 loss=5.782e-03	  weighted_average=6.604e-03	  c=4.890e+00
# It=2325	 loss=6.435e-03	  weighted_average=6.362e-03	  c=4.907e+00
# It=2350	 loss=5.906e-03	  weighted_average=5.977e-03	  c=4.866e+00
# It=2375	 loss=6.187e-03	  weighted_average=6.079e-03	  c=4.899e+00
# It=2400	 loss=6.612e-03	  weighted_average=5.724e-03	  c=4.895e+00
# It=2425	 loss=5.569e-03	  weighted_average=5.651e-03	  c=4.875e+00
# It=2450	 loss=5.437e-03	  weighted_average=5.813e-03	  c=4.942e+00
# Epoch 02465: reducing learning rate of group 0 to 1.3422e-05.
# It=2475	 loss=5.602e-03	  weighted_average=5.277e-03	  c=4.943e+00
# It=2500	 loss=5.662e-03	  weighted_average=6.033e-03	  c=4.965e+00
# It=2525	 loss=6.034e-03	  weighted_average=5.584e-03	  c=4.936e+00
# It=2550	 loss=5.229e-03	  weighted_average=5.478e-03	  c=4.961e+00
# It=2575	 loss=5.126e-03	  weighted_average=5.235e-03	  c=4.966e+00
# It=2600	 loss=5.699e-03	  weighted_average=5.037e-03	  c=4.949e+00
# It=2625	 loss=4.997e-03	  weighted_average=5.420e-03	  c=4.962e+00
# It=2650	 loss=5.317e-03	  weighted_average=5.534e-03	  c=4.966e+00
# Epoch 02666: reducing learning rate of group 0 to 1.0737e-05.
# It=2675	 loss=4.727e-03	  weighted_average=4.812e-03	  c=4.956e+00
# It=2700	 loss=5.185e-03	  weighted_average=5.547e-03	  c=4.945e+00
# It=2725	 loss=4.561e-03	  weighted_average=4.965e-03	  c=4.952e+00
# It=2750	 loss=4.747e-03	  weighted_average=5.102e-03	  c=4.969e+00
# It=2775	 loss=4.952e-03	  weighted_average=4.900e-03	  c=4.959e+00
# It=2800	 loss=4.827e-03	  weighted_average=4.692e-03	  c=4.987e+00
# It=2825	 loss=5.293e-03	  weighted_average=4.965e-03	  c=4.981e+00
# It=2850	 loss=5.371e-03	  weighted_average=4.697e-03	  c=4.977e+00
# Epoch 02867: reducing learning rate of group 0 to 8.5899e-06.
# It=2875	 loss=4.857e-03	  weighted_average=5.224e-03	  c=5.009e+00
# It=2900	 loss=5.407e-03	  weighted_average=4.606e-03	  c=5.010e+00
# It=2925	 loss=4.794e-03	  weighted_average=5.216e-03	  c=4.975e+00
# It=2950	 loss=4.941e-03	  weighted_average=6.171e-03	  c=4.940e+00
# It=2975	 loss=5.209e-03	  weighted_average=4.716e-03	  c=4.982e+00
# It=3000	 loss=4.714e-03	  weighted_average=4.698e-03	  c=4.977e+00
# It=3025	 loss=4.288e-03	  weighted_average=4.338e-03	  c=4.983e+00
# It=3050	 loss=4.551e-03	  weighted_average=4.329e-03	  c=4.952e+00
# Epoch 03068: reducing learning rate of group 0 to 6.8719e-06.
# It=3075	 loss=4.111e-03	  weighted_average=4.155e-03	  c=4.981e+00
# It=3100	 loss=4.248e-03	  weighted_average=4.607e-03	  c=4.983e+00
# It=3125	 loss=4.296e-03	  weighted_average=4.555e-03	  c=4.994e+00
# It=3150	 loss=4.204e-03	  weighted_average=4.515e-03	  c=5.014e+00
# It=3175	 loss=4.430e-03	  weighted_average=4.898e-03	  c=4.992e+00
# It=3200	 loss=4.078e-03	  weighted_average=4.147e-03	  c=5.002e+00
# It=3225	 loss=4.025e-03	  weighted_average=4.067e-03	  c=5.003e+00
# It=3250	 loss=4.681e-03	  weighted_average=4.129e-03	  c=5.010e+00
# Epoch 03269: reducing learning rate of group 0 to 5.4976e-06.
# It=3275	 loss=2.318e-02	  weighted_average=4.309e-02	  c=4.252e+00
# It=3300	 loss=1.480e-02	  weighted_average=1.493e-02	  c=4.487e+00
# It=3325	 loss=1.080e-02	  weighted_average=1.109e-02	  c=4.585e+00
# It=3350	 loss=1.027e-02	  weighted_average=9.838e-03	  c=4.653e+00
# It=3375	 loss=9.316e-03	  weighted_average=9.616e-03	  c=4.714e+00
# It=3400	 loss=1.152e-02	  weighted_average=8.181e-03	  c=4.685e+00
# It=3425	 loss=7.997e-03	  weighted_average=8.025e-03	  c=4.735e+00
# It=3450	 loss=7.657e-03	  weighted_average=7.932e-03	  c=4.779e+00
# Epoch 03470: reducing learning rate of group 0 to 4.3980e-06.
# It=3475	 loss=6.687e-03	  weighted_average=7.213e-03	  c=4.794e+00
# It=3500	 loss=6.958e-03	  weighted_average=6.926e-03	  c=4.816e+00
# It=3525	 loss=7.014e-03	  weighted_average=6.347e-03	  c=4.839e+00
# It=3550	 loss=7.256e-03	  weighted_average=6.653e-03	  c=4.822e+00
# It=3575	 loss=6.483e-03	  weighted_average=6.177e-03	  c=4.834e+00
# It=3600	 loss=5.500e-03	  weighted_average=6.020e-03	  c=4.831e+00
# It=3625	 loss=5.399e-03	  weighted_average=5.519e-03	  c=4.825e+00
# It=3650	 loss=5.918e-03	  weighted_average=5.771e-03	  c=4.848e+00
# Epoch 03671: reducing learning rate of group 0 to 3.5184e-06.
# It=3675	 loss=5.386e-03	  weighted_average=5.755e-03	  c=4.860e+00
# It=3700	 loss=5.644e-03	  weighted_average=5.799e-03	  c=4.855e+00
# It=3725	 loss=6.413e-03	  weighted_average=5.801e-03	  c=4.856e+00
# It=3750	 loss=6.439e-03	  weighted_average=5.278e-03	  c=4.859e+00
# It=3775	 loss=4.773e-03	  weighted_average=5.471e-03	  c=4.885e+00
# It=3800	 loss=4.818e-03	  weighted_average=5.950e-03	  c=4.874e+00
# It=3825	 loss=5.566e-03	  weighted_average=5.063e-03	  c=4.875e+00
# It=3850	 loss=4.807e-03	  weighted_average=4.971e-03	  c=4.882e+00
# Epoch 03872: reducing learning rate of group 0 to 2.8147e-06.
# It=3875	 loss=5.248e-03	  weighted_average=4.928e-03	  c=4.901e+00
# It=3900	 loss=5.273e-03	  weighted_average=5.209e-03	  c=4.891e+00
# It=3925	 loss=5.188e-03	  weighted_average=5.121e-03	  c=4.892e+00
# It=3950	 loss=4.363e-03	  weighted_average=4.821e-03	  c=4.896e+00
# It=3975	 loss=4.712e-03	  weighted_average=4.941e-03	  c=4.879e+00
# It=4000	 loss=4.785e-03	  weighted_average=4.571e-03	  c=4.884e+00
# It=4025	 loss=5.747e-03	  weighted_average=5.243e-03	  c=4.893e+00
# It=4050	 loss=5.117e-03	  weighted_average=4.573e-03	  c=4.898e+00
# Epoch 04073: reducing learning rate of group 0 to 2.2518e-06.
# It=4075	 loss=5.065e-03	  weighted_average=4.739e-03	  c=4.898e+00
# It=4100	 loss=5.022e-03	  weighted_average=5.308e-03	  c=4.902e+00
# It=4125	 loss=4.525e-03	  weighted_average=4.751e-03	  c=4.906e+00
# It=4150	 loss=4.410e-03	  weighted_average=4.781e-03	  c=4.904e+00
# It=4175	 loss=4.491e-03	  weighted_average=4.764e-03	  c=4.909e+00
# It=4200	 loss=4.919e-03	  weighted_average=4.269e-03	  c=4.893e+00
# It=4225	 loss=4.288e-03	  weighted_average=5.153e-03	  c=4.925e+00
# It=4250	 loss=5.006e-03	  weighted_average=5.380e-03	  c=4.884e+00
# Epoch 04274: reducing learning rate of group 0 to 1.8014e-06.
# It=4275	 loss=4.708e-03	  weighted_average=5.067e-03	  c=4.922e+00
# It=4300	 loss=4.567e-03	  weighted_average=4.315e-03	  c=4.915e+00
# It=4325	 loss=4.542e-03	  weighted_average=4.477e-03	  c=4.912e+00
# It=4350	 loss=4.452e-03	  weighted_average=4.525e-03	  c=4.919e+00
# It=4375	 loss=4.814e-03	  weighted_average=4.665e-03	  c=4.916e+00
# It=4400	 loss=4.597e-03	  weighted_average=4.264e-03	  c=4.912e+00
# It=4425	 loss=4.793e-03	  weighted_average=4.192e-03	  c=4.911e+00
# It=4450	 loss=4.429e-03	  weighted_average=4.468e-03	  c=4.917e+00
# Epoch 04475: reducing learning rate of group 0 to 1.4412e-06.
# It=4475	 loss=4.554e-03	  weighted_average=4.497e-03	  c=4.917e+00
# It=4500	 loss=4.653e-03	  weighted_average=4.544e-03	  c=4.920e+00
# It=4525	 loss=4.438e-03	  weighted_average=4.333e-03	  c=4.917e+00
# It=4550	 loss=5.383e-03	  weighted_average=4.352e-03	  c=4.925e+00
# It=4575	 loss=4.445e-03	  weighted_average=4.428e-03	  c=4.938e+00
# It=4600	 loss=4.323e-03	  weighted_average=4.116e-03	  c=4.933e+00
# It=4625	 loss=3.913e-03	  weighted_average=3.960e-03	  c=4.936e+00
# It=4650	 loss=4.664e-03	  weighted_average=4.656e-03	  c=4.944e+00
# It=4675	 loss=4.199e-03	  weighted_average=4.006e-03	  c=4.935e+00
# Epoch 04676: reducing learning rate of group 0 to 1.1529e-06.
# It=4700	 loss=4.286e-03	  weighted_average=3.941e-03	  c=4.939e+00
# It=4725	 loss=4.643e-03	  weighted_average=4.204e-03	  c=4.929e+00
# It=4750	 loss=4.348e-03	  weighted_average=4.333e-03	  c=4.927e+00
# It=4775	 loss=4.088e-03	  weighted_average=3.995e-03	  c=4.925e+00
# It=4800	 loss=4.207e-03	  weighted_average=4.127e-03	  c=4.931e+00
# It=4825	 loss=4.168e-03	  weighted_average=4.331e-03	  c=4.923e+00
# It=4850	 loss=3.598e-03	  weighted_average=4.122e-03	  c=4.930e+00
# It=4875	 loss=4.067e-03	  weighted_average=3.894e-03	  c=4.931e+00
# Epoch 04877: reducing learning rate of group 0 to 9.2234e-07.
# It=4900	 loss=4.081e-03	  weighted_average=3.854e-03	  c=4.926e+00
# It=4925	 loss=3.942e-03	  weighted_average=3.919e-03	  c=4.925e+00
# It=4950	 loss=4.877e-03	  weighted_average=4.425e-03	  c=4.928e+00
# It=4975	 loss=4.130e-03	  weighted_average=4.189e-03	  c=4.928e+00
# It=5000	 loss=4.405e-03	  weighted_average=4.050e-03	  c=4.932e+00
# It=5025	 loss=3.736e-03	  weighted_average=4.061e-03	  c=4.934e+00
# It=5050	 loss=4.691e-03	  weighted_average=3.852e-03	  c=4.925e+00
# It=5075	 loss=3.662e-03	  weighted_average=4.095e-03	  c=4.930e+00
# Epoch 05078: reducing learning rate of group 0 to 7.3787e-07.
# It=5100	 loss=4.568e-03	  weighted_average=4.042e-03	  c=4.931e+00
# It=5125	 loss=4.504e-03	  weighted_average=4.301e-03	  c=4.933e+00
# It=5150	 loss=3.926e-03	  weighted_average=3.818e-03	  c=4.939e+00
# It=5175	 loss=4.317e-03	  weighted_average=4.122e-03	  c=4.937e+00
# It=5200	 loss=3.650e-03	  weighted_average=4.353e-03	  c=4.932e+00
# It=5225	 loss=3.826e-03	  weighted_average=3.957e-03	  c=4.926e+00
# It=5250	 loss=3.838e-03	  weighted_average=3.819e-03	  c=4.934e+00
# It=5275	 loss=4.173e-03	  weighted_average=3.774e-03	  c=4.927e+00
# Epoch 05279: reducing learning rate of group 0 to 5.9030e-07.
# It=5300	 loss=4.132e-03	  weighted_average=4.022e-03	  c=4.928e+00
# It=5325	 loss=3.647e-03	  weighted_average=3.880e-03	  c=4.931e+00
# It=5350	 loss=4.772e-03	  weighted_average=4.148e-03	  c=4.940e+00
# It=5375	 loss=4.519e-03	  weighted_average=4.369e-03	  c=4.946e+00
# It=5400	 loss=4.069e-03	  weighted_average=4.028e-03	  c=4.951e+00
# It=5425	 loss=3.904e-03	  weighted_average=4.150e-03	  c=4.936e+00
# It=5450	 loss=3.613e-03	  weighted_average=3.854e-03	  c=4.938e+00
# It=5475	 loss=3.930e-03	  weighted_average=4.060e-03	  c=4.952e+00
# Epoch 05480: reducing learning rate of group 0 to 4.7224e-07.
# It=5500	 loss=4.215e-03	  weighted_average=3.797e-03	  c=4.946e+00
# It=5525	 loss=3.920e-03	  weighted_average=3.863e-03	  c=4.952e+00
# It=5550	 loss=3.776e-03	  weighted_average=4.281e-03	  c=4.942e+00
# It=5575	 loss=3.527e-03	  weighted_average=4.041e-03	  c=4.943e+00
# It=5600	 loss=3.942e-03	  weighted_average=3.873e-03	  c=4.947e+00
# It=5625	 loss=4.146e-03	  weighted_average=4.283e-03	  c=4.953e+00
# It=5650	 loss=4.398e-03	  weighted_average=4.224e-03	  c=4.954e+00
# It=5675	 loss=4.005e-03	  weighted_average=3.983e-03	  c=4.949e+00
# Epoch 05681: reducing learning rate of group 0 to 3.7779e-07.
# It=5700	 loss=3.662e-03	  weighted_average=3.657e-03	  c=4.947e+00
# It=5725	 loss=3.638e-03	  weighted_average=3.805e-03	  c=4.953e+00
# It=5750	 loss=4.481e-03	  weighted_average=4.098e-03	  c=4.947e+00
# It=5775	 loss=4.154e-03	  weighted_average=3.978e-03	  c=4.953e+00
# It=5800	 loss=4.688e-03	  weighted_average=3.791e-03	  c=4.950e+00
# It=5825	 loss=4.301e-03	  weighted_average=4.278e-03	  c=4.955e+00
# It=5850	 loss=4.121e-03	  weighted_average=3.822e-03	  c=4.945e+00
# It=5875	 loss=3.801e-03	  weighted_average=4.172e-03	  c=4.957e+00
# Epoch 05882: reducing learning rate of group 0 to 3.0223e-07.
# It=5900	 loss=4.106e-03	  weighted_average=3.861e-03	  c=4.952e+00
# It=5925	 loss=3.932e-03	  weighted_average=3.926e-03	  c=4.946e+00
# It=5950	 loss=3.848e-03	  weighted_average=4.384e-03	  c=4.945e+00
# It=5975	 loss=3.965e-03	  weighted_average=3.820e-03	  c=4.948e+00
# It=6000	 loss=4.031e-03	  weighted_average=3.734e-03	  c=4.941e+00
# It=6025	 loss=4.178e-03	  weighted_average=3.973e-03	  c=4.945e+00
# It=6050	 loss=3.875e-03	  weighted_average=3.769e-03	  c=4.946e+00
# It=6075	 loss=3.565e-03	  weighted_average=3.730e-03	  c=4.950e+00
# Epoch 06083: reducing learning rate of group 0 to 2.4179e-07.
# It=6100	 loss=3.659e-03	  weighted_average=3.813e-03	  c=4.943e+00
# It=6125	 loss=3.698e-03	  weighted_average=3.639e-03	  c=4.948e+00
# It=6150	 loss=3.848e-03	  weighted_average=4.055e-03	  c=4.947e+00
# It=6175	 loss=3.538e-03	  weighted_average=3.478e-03	  c=4.946e+00
# It=6200	 loss=3.588e-03	  weighted_average=3.655e-03	  c=4.947e+00
# It=6225	 loss=3.571e-03	  weighted_average=3.729e-03	  c=4.947e+00
# It=6250	 loss=3.837e-03	  weighted_average=3.617e-03	  c=4.944e+00
# It=6275	 loss=3.281e-03	  weighted_average=3.584e-03	  c=4.943e+00
# Epoch 06284: reducing learning rate of group 0 to 1.9343e-07.
# It=6300	 loss=3.918e-03	  weighted_average=3.631e-03	  c=4.946e+00
# It=6325	 loss=3.439e-03	  weighted_average=3.731e-03	  c=4.955e+00
# It=6350	 loss=3.752e-03	  weighted_average=5.384e-03	  c=4.958e+00
# It=6375	 loss=3.717e-03	  weighted_average=3.911e-03	  c=4.947e+00
# It=6400	 loss=3.785e-03	  weighted_average=3.960e-03	  c=4.947e+00
# It=6425	 loss=3.451e-03	  weighted_average=3.537e-03	  c=4.950e+00
# It=6450	 loss=4.138e-03	  weighted_average=3.835e-03	  c=4.947e+00
# It=6475	 loss=3.810e-03	  weighted_average=3.877e-03	  c=4.953e+00
# Epoch 06485: reducing learning rate of group 0 to 1.5474e-07.
# It=6500	 loss=3.413e-03	  weighted_average=3.549e-03	  c=4.949e+00
# It=6525	 loss=3.870e-03	  weighted_average=3.483e-03	  c=4.952e+00
# It=6550	 loss=3.754e-03	  weighted_average=3.374e-03	  c=4.952e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 50
#      47 OPTIMIZER.zero_grad()
#      49 # Backward pass: compute gradient of the loss with respect to model parameters
# ---> 50 loss.backward()
#      52 # Calling the step function on an Optimizer makes an update to its
#      53 # parameters
#      54 OPTIMIZER.step()
#
# File ~\miniconda3\envs\geodesynet\lib\site-packages\torch\_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File ~\miniconda3\envs\geodesynet\lib\site-packages\torch\autograd\__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
# Here we restore the learned parameters of the best model of the run
for layer in model.state_dict():
    model.state_dict()[layer] = best_model_state_dict[layer]

# %% [markdown]
# # 3 - Interpretation of the neural density field learned

# %%
# First lets have a look at the training loss history
plt.figure()
abscissa = np.cumsum(n_inferences)
plt.semilogy(abscissa,  loss_log)
plt.semilogy(abscissa,  weighted_average_log)
plt.xlabel("Thousands of model evaluations x 10")
plt.ylabel("Loss")
plt.legend(["Loss","Weighted Average Loss"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Lets have a look at the neural density field.
# First with a rejection plot
gravann.plot_model_rejection(model, encoding, views_2d=True, bw=True, N=1500, alpha=0.1, s=50, c=c, crop_p=0.1, progressbar=True)
# Out:
# Sampling points...: 1617it [00:00, 2207.27it/s]
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### Saving the model

# %%
# Uncomment to save the model
torch.save(model.state_dict(), MODEL_FILENAME)
