# %% [markdown]
# # Loading results

# %%
from gravann.io import csv_input_loader

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
FILEPATH = "F:\\results"

data = csv_input_loader.read_result_csv(FILEPATH)

# %%
data[["Target Sampler Domain", "Noise Method", "relRMSE@Altitude_0", "relRMSE@Altitude_6"]]
# Out:
#                   Sample Type  Model                Loss         Encoding  \
# 0  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 1  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 2  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 3  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 4  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 5  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 0  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 1  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 2  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 3  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 4  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# 5  churyumov-gerasimenko  ACC  siren  normalized_L1_loss  direct_encoding
# ...

# %%
data[["Target Sampler Domain", "Noise Method", "relRMSE@Altitude_0", "relRMSE@Altitude_6"]]
# Out:
#   Target Sampler Domain   Noise Method  relRMSE@Altitude_0  relRMSE@Altitude_6
# 0            [0.0, 1.0]       gaussian            0.303602            0.009236
# 1            [1.0, 3.0]       gaussian            0.816195            0.016914
# 2            [3.0, 5.0]       gaussian            1.217371            0.093253
# 3            [0.0, 1.0]  constant_bias            0.413457            0.133446
# 4            [1.0, 3.0]  constant_bias            0.655040            0.002331
# 5            [3.0, 5.0]  constant_bias            0.793952            0.013293
# 0            [0.0, 1.0]       gaussian            0.309006            0.008752
# 1            [1.0, 3.0]       gaussian            1.445518            0.172567
# 2            [3.0, 5.0]       gaussian            1.350803            0.123131
# 3            [0.0, 1.0]  constant_bias            0.415816            0.134764
# 4            [1.0, 3.0]  constant_bias            0.642230            0.001997
# ...
